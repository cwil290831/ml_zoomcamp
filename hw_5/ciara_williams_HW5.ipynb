# %% [markdown]
# # Installation and Imports

# %%
data = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv"
# !wget $data
# Out:
# --2025-10-27 20:16:50--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80876 (79K) [text/plain]
# Saving to: ‘course_lead_scoring.csv’
#
# course_lead_scoring 100%[===================>]  78.98K  --.-KB/s    in 0.002s
#
# 2025-10-27 20:16:50 (46.4 MB/s) - ‘course_lead_scoring.csv’ saved [80876/80876]

# %% [markdown]
# ## Question 1
#
# * Install `uv`
# * What's the version of uv you installed?
# * Use `--version` to find out
# - 0.9.5

# %% [markdown]
# ### Initialize an empty uv project
#
# You should create an empty folder for homework
# and do it there.

# %% [markdown]
# ## Question 2
#
# * Use uv to install Scikit-Learn version 1.6.1
# * What's the first hash for Scikit-Learn you get in the lock file?
# * Include the entire string starting with sha256:, don't include quotes
#     - sha256:20e9e49ecd130598f1ca38a1d85090e1a600147b9c02fa6f15d69cb53d968fda", size = 7193136, upload-time = "2025-09-09T08:21:29.075Z

# %% [markdown]
# # Models

# %% [markdown]
# We have prepared a pipeline with a dictionary vectorizer and a model.
#
#
# It was trained (roughly) using the code below and saved using **Pickle**.
#
# ```python
# categorical = ['lead_source']
# numeric = ['number_of_courses_viewed', 'annual_income']
#
# df[categorical] = df[categorical].fillna('NA')
# df[numeric] = df[numeric].fillna(0)
#
# train_dict = df[categorical + numeric].to_dict(orient='records')
#
# pipeline = make_pipeline(
#     DictVectorizer(),
#     LogisticRegression(solver='liblinear')
# )
#
# pipeline.fit(train_dict, y_train)
# ```

# %%
pipeline = "https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin"
# !wget $pipeline
# Out:
# --2025-10-27 20:16:55--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin [following]
# --2025-10-27 20:16:55--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1300 (1.3K) [application/octet-stream]
# ...

# %% [markdown]
# ## Question 3
#
# Let's use the model!
#
# Score the following record
# ```json
# {
#     "lead_source": "paid_ads",
#     "number_of_courses_viewed": 2,
#     "annual_income": 79276.0
# }
# ```
#
# 1. Write a script for loading the pipeline with pickle
#     - [predict.py]
# 2. What's the probability that this lead will convert?
#     - 0.5336

# %% [markdown]
# # Web Service

# %% [markdown]
# ## Question 4
#
# Now let's serve this model as a web service.
#
# Use the following:
# ```python
# url = "YOUR_URL"
# client = {
#     "lead_source": "organic_search",
#     "number_of_courses_viewed": 4,
#     "annual_income": 80304.0
# }
# requests.post(url, json=client).json()
# ```
#
# 1. Install FastAPI.
# 2. Write FastAPI code for serving the model.
# 3. Score the client using `requests`.
# 4. What's the probability that this client will get a subscription?
#     - 0.5340

# %% [markdown]
# # Docker

# %% [markdown]
# ## Question 5
# Base Image: `agrigorev/zoomcamp-model:2025`
#
# 1. Install Docker
# 2. Download Base Image
# 3. So what's the size of this base image?
#     - 121MB

# %% [markdown]
# ## Dockerfile
#
# 1. Create your own `Dockerfile` based on the image we prepared.
# 2. Install dependencies from pyproject.toml
# 3. Build the Docker Image.

# %% [markdown]
# ## Question 6
#
# 1. Run Docker Container
# 2. Score using client from Question 4.
# 3. What's the probability that this lead will convert?
#     - 0.5430
